# %% [markdown]
# # Полносвязные нейронные сети

# %% [markdown]
# В этом упражнении мы реализуем полносвязные сети, используя модульный подход. Для каждого слоя мы реализуем функции `forward` и `backward`. Функция `forward` получает входы, веса и другие параметры и возвращает выход, а также объект `cache`, в котором сохраняются данные, необходимые для обратного прохода, например:
#
# ```python
# def layer_forward(x, w):
#   """Получает входы x и веса w"""
#   # Выполняем вычисления ...
#   z = # ... промежуточные результаты
#   # ...
#   out = # ... итоговый выход
#   cache = (x, w, z, out) # сохраняем всё нужное для backward
#   return out, cache
# ```
#
# Функция `backward` получает производные по выходу и объект `cache`, после чего вычисляет производные по входам и весам:
#
# ```python
# def layer_backward(dout, cache):
#   """Получает производные по выходу и кэш"""
#   # Распаковываем значения из cache
#   x, w, z, out = cache
#   # Выполняем вычисления ...
#   dx = # градиент по x
#   dw = # градиент по w
#   return dx, dw
# ```
#
# После реализации всех слоёв мы соберём их в двухслойную сеть с архитектурой `affine - relu - affine - softmax`.

# %% [markdown]
# ## Введение
# Ниже предстоит реализовать линейный слой и слой RELU. Как было рассмотрено ранее, на линейном слое выполняется линейное преобразование, а на слое RELU - добавляется нелинейность. Поскольку у нас стоит задача классификации (многоклассовой), то ответы мы будем получать через Softmax
#
#
# Перед выполнением задания нужно скачать датасет - в папке datasets есть файл с указанием путей для скачивания

# %%
# Базовая настройка окружения
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from classifiers.fc_net import *
from utils.data_utils import get_CIFAR10_data
from utils.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from utils.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)  # размер графиков по умолчанию
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Автоперезагрузка внешних модулей
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Возвращает максимальную относительную ошибку."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Загружаем предварительно обработанный CIFAR-10
data = get_CIFAR10_data()
for k, v in list(data.items()):
  print(('%s: ' % k, v.shape))
# Out:
# c:\Users\alesy\PycharmProjects\pythonProject\sem_04\MIPT_ML_CV\Homeworks\hw1\utils\data_utils.py:16: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   return pickle.load(f, encoding="latin1")
# ('X_train: ', (49000, 3, 32, 32))
# ('y_train: ', (49000,))
# ('X_val: ', (1000, 3, 32, 32))
# ('y_val: ', (1000,))
# ('X_test: ', (1000, 3, 32, 32))
# ('y_test: ', (1000,))

# %% [markdown]
# # Полносвязный слой: прямой проход
#
# Откройте файл `classifiers/layers.py` и реализуйте функцию `affine_forward`.
#
# После этого можно проверить реализацию, запустив следующую ячейку:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  9.769849468192957e-10

# %% [markdown]
# # Полносвязный слой: обратный проход
#
# Теперь реализуйте функцию `affine_backward` и проверьте её с помощью численной проверки градиента.

# %%
# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  5.399100368651805e-11
# dw error:  9.904211865398145e-11
# db error:  2.4122867568119087e-11

# %% [markdown]
# # Активация ReLU: прямой проход
#
# Реализуйте прямой проход для функции активации ReLU в `relu_forward`, а затем проверьте реализацию следующей ячейкой:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# # Активация ReLU: обратный проход
#
# Теперь реализуйте обратный проход для ReLU в `relu_backward` и проверьте его с помощью численной проверки градиента:

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# ## Теоретический вопрос 1
#
# Мы просили реализовать только ReLU, но в нейросетях можно использовать много разных функций активации, у каждой есть свои плюсы и минусы. Одна из частых проблем — исчезающие градиенты, когда во время обратного распространения градиент становится равным нулю или очень близким к нулю.
#
# Какие из перечисленных ниже функций страдают от этой проблемы? Если рассматривать функции в одномерном случае, то для каких входных значений это происходит?
#
# 1. `sigmoid`
# 2. `ReLU`
# 3. `Leaky RELU`
#
# ### Ваш ответ:
# `sigmoid` при больших отрицательных и больших положительных числах стремится к нулю, экспоненциально затухает функция $\sigma(x) = \frac{1}{1 + e^{-x}}$, а производная равна $\sigma'(x) = \frac{e^{-x}}{(1 + e^{-x})^2} = \frac{1}{1 + e^{-x}} * (1 - \frac{1}{1 + e^{-x}}) = \sigma(x) * (1 - \sigma(x))$
#
# `ReLU` при отрицательных x

# %% [markdown]
# # «Сэндвич»-слои
#
# В нейронных сетях часто встречаются типовые комбинации слоёв. Например, полносвязный слой часто сразу сопровождается ReLU. Чтобы не писать один и тот же код много раз, в файле `classifiers/layer_utils.py` определены составные слои.
#
# Сейчас посмотрите на функции `affine_relu_forward` и `affine_relu_backward`, а затем запустите следующую ячейку для численной проверки градиентов обратного прохода:

# %%
from classifiers.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  2.299579177309368e-11
# dw error:  8.162011105764925e-11
# db error:  7.826724021458994e-12

# %% [markdown]
# # Слой потерь: Softmax
#
# Теперь реализуйте функцию потерь и градиент для softmax в функции `softmax_loss` в файле `classifiers/layers.py`.
#
# Корректность реализации можно проверить следующей ячейкой:

# %%
np.random.seed(231)
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)


dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing softmax_loss:
# loss:  2.3025458445007376
# dx error:  8.234144091578429e-09

# %% [markdown]
# # Двухслойная сеть
#
# Откройте файл `classifiers/fc_net.py` и завершите реализацию класса `TwoLayerNet`. Внимательно прочитайте код, чтобы понять API. После этого можно запустить следующую ячейку для проверки реализации.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.83e-08
# W2 relative error: 3.31e-10
# b1 relative error: 9.83e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.56e-08
# b2 relative error: 7.76e-10

# %% [markdown]
# # Solver
#
# Откройте файл `utils/solver.py` и ознакомьтесь с его API. Затем с помощью объекта `Solver` обучите `TwoLayerNet`, чтобы добиться примерно точности на валидационной выборке как минимум более 35%. В качестве оптимизатора можно взять на данном уже реализованный в optim.py, либо написать свой

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10

# Базовая двухслойная сеть 
model = TwoLayerNet(
    input_dim=input_size,
    hidden_dim=hidden_size,
    num_classes=num_classes
)

solver = Solver(
    model, data,
    update_rule='sgd', # если запустить с sgd_momentum, то сразу получается 48 процентов
    optim_config={
        'learning_rate': 1e-4,
    },
    lr_decay=0.95,
    num_epochs=5, batch_size=200,
    print_every=100
)

solver.train()
# Out:
# (Iteration 1 / 1225) loss: 2.300428
# (Epoch 0 / 5) train acc: 0.142000; val_acc: 0.119000
# (Iteration 101 / 1225) loss: 2.261639
# (Iteration 201 / 1225) loss: 2.172068
# (Epoch 1 / 5) train acc: 0.230000; val_acc: 0.251000
# (Iteration 301 / 1225) loss: 2.074678
# (Iteration 401 / 1225) loss: 2.067968
# (Epoch 2 / 5) train acc: 0.320000; val_acc: 0.293000
# (Iteration 501 / 1225) loss: 1.951871
# (Iteration 601 / 1225) loss: 1.799486
# (Iteration 701 / 1225) loss: 1.801509
# (Epoch 3 / 5) train acc: 0.326000; val_acc: 0.322000
# (Iteration 801 / 1225) loss: 1.933847
# (Iteration 901 / 1225) loss: 1.925852
# (Epoch 4 / 5) train acc: 0.364000; val_acc: 0.346000
# (Iteration 1001 / 1225) loss: 1.870235
# (Iteration 1101 / 1225) loss: 1.813235
# (Iteration 1201 / 1225) loss: 1.800604
# (Epoch 5 / 5) train acc: 0.368000; val_acc: 0.377000

# %% [markdown]
# # Отладка обучения
#
# С параметрами по умолчанию точность на валидации должна получиться около `0.36`. Это не очень высокий результат.
#
# Один способ понять, что идёт не так, — построить графики функции потерь и точности на обучающей и валидационной выборках во время оптимизации.
#
# Другой способ — визуализировать веса, которые выучила сеть в первом слое. В задачах компьютерного зрения первый слой часто начинает выделять простые шаблоны: границы, цветовые контрасты, текстуры. Если веса выглядят как шум, это намекает на проблемы с настройкой обучения.

# %%
# Визуализация функции потерь и точности на train / val

plt.subplot(2, 1, 1)
plt.title('Функция потерь при обучении')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Итерация')

plt.subplot(2, 1, 2)
plt.title('Точность')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Эпоха')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %%
from utils.vis_utils import visualize_grid

# Визуализация весов первого слоя сети
def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(model)

# %% [markdown]
# # Подбор гиперпараметров
#
# **Что здесь не так?** По графикам выше видно, что функция потерь убывает почти линейно. Это часто говорит о том, что скорость обучения слишком мала. Кроме того, между обучающей и валидационной точностью почти нет разрыва, а значит, модель, скорее всего, имеет недостаточную ёмкость и её стоит увеличить.
#
# С другой стороны, слишком большая модель может начать переобучаться: тогда обучающая точность станет заметно выше валидационной. Ваша цель — подобрать такие гиперпараметры, чтобы получить качество выше `48%` на валидации.
# При выборе варьируемых гиперпараметров модно отталкиваться от параметров TwoLayerNet

# %%
best_model = None
best_val_acc = 0.0

hidden_dims = [100, 150, 200]
learning_rates = [1e-3, 1e-4, 1e-5]
regularizations = [0.0, 0.4, 0.7]
weight_scales = [1e-4, 1e-3, 1e-2]

for hidden_dim in hidden_dims:
    for lr in learning_rates:
        for reg in regularizations:
            for weight_scale in weight_scales:

                model = TwoLayerNet(
                    input_dim=input_size,
                    hidden_dim=hidden_dim,
                    num_classes=num_classes,
                    weight_scale=weight_scale,
                    reg=reg
                )
                
                solver = Solver(
                    model,
                    data,
                    update_rule='sgd',
                    optim_config={
                        'learning_rate': lr,
                    },
                    lr_decay=0.95,
                    num_epochs=5, batch_size=200,
                    print_every=500
                )
                
                solver.train()
                
                val_acc = solver.best_val_acc
                
                if val_acc > best_val_acc:
                    best_val_acc = val_acc
                    best_model = model
                    print(f"\nVal_acc = {val_acc}")
                    print(f"Params: hidden={hidden_dim}, lr={lr}, reg={reg}, scale={weight_scale}\n")
                else:
                    print()


print(f"Best val_acc = {best_val_acc}")
# Out:
# (Iteration 1 / 1225) loss: 2.302572
# (Epoch 0 / 5) train acc: 0.142000; val_acc: 0.143000
# (Epoch 1 / 5) train acc: 0.404000; val_acc: 0.417000
# (Epoch 2 / 5) train acc: 0.464000; val_acc: 0.442000
# (Iteration 501 / 1225) loss: 1.600257
# (Epoch 3 / 5) train acc: 0.490000; val_acc: 0.458000
# (Epoch 4 / 5) train acc: 0.509000; val_acc: 0.475000
# (Iteration 1001 / 1225) loss: 1.518787
# (Epoch 5 / 5) train acc: 0.524000; val_acc: 0.485000
#
# Val_acc = 0.485
# Params: hidden=100, lr=0.001, reg=0.0, scale=0.0001
#
# (Iteration 1 / 1225) loss: 2.299809
# (Epoch 0 / 5) train acc: 0.158000; val_acc: 0.152000
# (Epoch 1 / 5) train acc: 0.418000; val_acc: 0.448000
# (Epoch 2 / 5) train acc: 0.463000; val_acc: 0.456000
# (Iteration 501 / 1225) loss: 1.559376
# (Epoch 3 / 5) train acc: 0.502000; val_acc: 0.477000
# (Epoch 4 / 5) train acc: 0.514000; val_acc: 0.479000
# (Iteration 1001 / 1225) loss: 1.222021
# (Epoch 5 / 5) train acc: 0.563000; val_acc: 0.496000
#
# Val_acc = 0.496
# Params: hidden=100, lr=0.001, reg=0.0, scale=0.001
#
# (Iteration 1 / 1225) loss: 4.407107
# (Epoch 0 / 5) train acc: 0.147000; val_acc: 0.141000
# (Epoch 1 / 5) train acc: 0.408000; val_acc: 0.398000
# (Epoch 2 / 5) train acc: 0.428000; val_acc: 0.425000
# (Iteration 501 / 1225) loss: 1.713521
# (Epoch 3 / 5) train acc: 0.456000; val_acc: 0.447000
# (Epoch 4 / 5) train acc: 0.473000; val_acc: 0.446000
# (Iteration 1001 / 1225) loss: 1.449525
# (Epoch 5 / 5) train acc: 0.497000; val_acc: 0.472000
#
# (Iteration 1 / 1225) loss: 2.303165
# (Epoch 0 / 5) train acc: 0.136000; val_acc: 0.123000
# (Epoch 1 / 5) train acc: 0.379000; val_acc: 0.392000
# (Epoch 2 / 5) train acc: 0.453000; val_acc: 0.437000
# (Iteration 501 / 1225) loss: 1.611618
# (Epoch 3 / 5) train acc: 0.488000; val_acc: 0.471000
# (Epoch 4 / 5) train acc: 0.495000; val_acc: 0.464000
# (Iteration 1001 / 1225) loss: 1.380285
# (Epoch 5 / 5) train acc: 0.507000; val_acc: 0.478000
#
# (Iteration 1 / 1225) loss: 2.364669
# (Epoch 0 / 5) train acc: 0.122000; val_acc: 0.121000
# (Epoch 1 / 5) train acc: 0.446000; val_acc: 0.438000
# (Epoch 2 / 5) train acc: 0.468000; val_acc: 0.452000
# (Iteration 501 / 1225) loss: 1.538222
# (Epoch 3 / 5) train acc: 0.494000; val_acc: 0.478000
# (Epoch 4 / 5) train acc: 0.492000; val_acc: 0.488000
# (Iteration 1001 / 1225) loss: 1.463618
# (Epoch 5 / 5) train acc: 0.520000; val_acc: 0.479000
#
# (Iteration 1 / 1225) loss: 10.641215
# (Epoch 0 / 5) train acc: 0.147000; val_acc: 0.144000
# (Epoch 1 / 5) train acc: 0.413000; val_acc: 0.410000
# (Epoch 2 / 5) train acc: 0.475000; val_acc: 0.442000
# (Iteration 501 / 1225) loss: 5.753012
# (Epoch 3 / 5) train acc: 0.450000; val_acc: 0.468000
# (Epoch 4 / 5) train acc: 0.501000; val_acc: 0.483000
# (Iteration 1001 / 1225) loss: 4.334632
# (Epoch 5 / 5) train acc: 0.512000; val_acc: 0.478000
#
# (Iteration 1 / 1225) loss: 2.303645
# (Epoch 0 / 5) train acc: 0.143000; val_acc: 0.172000
# (Epoch 1 / 5) train acc: 0.429000; val_acc: 0.389000
# (Epoch 2 / 5) train acc: 0.462000; val_acc: 0.449000
# (Iteration 501 / 1225) loss: 1.712071
# (Epoch 3 / 5) train acc: 0.488000; val_acc: 0.468000
# (Epoch 4 / 5) train acc: 0.531000; val_acc: 0.487000
# (Iteration 1001 / 1225) loss: 1.551384
# (Epoch 5 / 5) train acc: 0.509000; val_acc: 0.484000
#
# (Iteration 1 / 1225) loss: 2.411665
# (Epoch 0 / 5) train acc: 0.136000; val_acc: 0
# (Epoch 5 / 5) train acc: 0.538000; val_acc: 0.487000
#
# (Iteration 1 / 1225) loss: 4.425737
# (Epoch 0 / 5) train acc: 0.178000; val_acc: 0.171000
# (Epoch 1 / 5) train acc: 0.425000; val_acc: 0.428000
# (Epoch 2 / 5) train acc: 0.442000; val_acc: 0.434000
# (Iteration 501 / 1225) loss: 1.610822
# (Epoch 3 / 5) train acc: 0.438000; val_acc: 0.399000
# (Epoch 4 / 5) train acc: 0.498000; val_acc: 0.453000
# (Iteration 1001 / 1225) loss: 1.477065
# (Epoch 5 / 5) train acc: 0.499000; val_acc: 0.494000
#
# (Iteration 1 / 1225) loss: 2.303480
# (Epoch 0 / 5) train acc: 0.129000; val_acc: 0.127000
# (Epoch 1 / 5) train acc: 0.387000; val_acc: 0.402000
# (Epoch 2 / 5) train acc: 0.433000; val_acc: 0.438000
# (Iteration 501 / 1225) loss: 1.681146
# (Epoch 3 / 5) train acc: 0.480000; val_acc: 0.451000
# (Epoch 4 / 5) train acc: 0.530000; val_acc: 0.466000
# (Iteration 1001 / 1225) loss: 1.378859
# (Epoch 5 / 5) train acc: 0.536000; val_acc: 0.493000
#
# (Iteration 1 / 1225) loss: 2.398706
# (Epoch 0 / 5) train acc: 0.100000; val_acc: 0.089000
# (Epoch 1 / 5) train acc: 0.433000; val_acc: 0.455000
# (Epoch 2 / 5) train acc: 0.476000; val_acc: 0.461000
# (Iteration 501 / 1225) loss: 1.468089
# (Epoch 3 / 5) train acc: 0.487000; val_acc: 0.487000
# (Epoch 4 / 5) train acc: 0.517000; val_acc: 0.489000
# (Iteration 1001 / 1225) loss: 1.461619
# (Epoch 5 / 5) train acc: 0.499000; val_acc: 0.496000
#
# (Iteration 1 / 1225) loss: 14.089953
# (Epoch 0 / 5) train acc: 0.127000; val_acc: 0.127000
# (Epoch 1 / 5) train acc: 0.412000; val_acc: 0.423000
# (Epoch 2 / 5) train acc: 0.436000; val_acc: 0.430000
# (Iteration 501 / 1225) loss: 7.773561
# (Epoch 3 / 5) train acc: 0.456000; val_acc: 0.447000
# (Epoch 4 / 5) train acc: 0.501000; val_acc: 0.446000
# (Iteration 1001 / 1225) loss: 5.760999
# (Epoch 5 / 5) train acc: 0.515000; val_acc: 0.487000
#
# (Iteration 1 / 1225) loss: 2.304206
# (Epoch 0 / 5) train acc: 0.148000; val_acc: 0.154000
# (Epoch 1 / 5) train acc: 0.418000; val_acc: 0.406000
# (Epoch 2 / 5) train acc: 0.461000; val_acc: 0.459000
# (Iteration 501 / 1225) loss: 1.702771
# (Epoch 3 / 5) train acc: 0.489000; val_acc: 0.446000
# (Epoch 4 / 5) train acc: 0.490000; val_acc: 0.489000
# (Iteration 1001 / 1225) loss: 1.672708
# (Epoch 5 / 5) train acc: 0.501000; val_acc: 0.499000
#
# (Iteration 1 / 1225) loss: 2.464720
# (Epoch 0 / 5) train acc: 0.106000; val_acc: 0.129000
# (Epoch 1 / 5) train acc: 0.427000; val_acc: 0.425000
# (Epoch 2 / 5) train acc: 0.468000; val_acc: 0.453000
# (Iteration 501 / 1225) loss: 1.647509
# (Epoch 3 / 5) train acc: 0.502000; val_acc: 0.473000
# (Epoch 4 / 5) train acc: 0.523000; val_acc: 0.488000
# (Iteration 1001 / 1225) loss: 1.612360
# (Epoch 5 / 5) train acc: 0.525000; val_acc: 0.509000
#
# Val_acc = 0.509
# Params: hidden=150, lr=0.001, reg=0.7, scale=0.001
#
# (Iteration 1 / 1225) loss: 21.849117
# (Epoch 0 / 5) train acc: 0.143000; val_acc: 0.144000
# (Epoch 1 / 5) train acc: 0.445000; val_acc: 0.433000
# (Epoch 2 / 5) train acc: 0.441000; val_acc: 0.441000
# (Iteration 501 / 1225) loss: 9.714435
# (Epoch 3 / 5) train acc: 0.503000; val_acc: 0.466000
# (Epoch 4 / 5) train acc: 0.497000; val_acc: 0.480000
# (Iteration 1001 / 1225) loss: 5.894243
# (Epoch 5 / 5) train acc: 0.474000; val_acc: 0.484000
#
# (Iteration 1 / 1225) loss: 2.302604
# (Epoch 0 / 5) train acc: 0.076000; val_acc: 0.079000
# (Epoch 1 / 5) train acc: 0.157000; val_acc: 0.183000
# (Epoch 2 / 5) train acc: 0.222000; val_acc: 0.243000
# (Iteration 501 / 1225) loss: 2.142418
# (Epoch 3 / 5) train acc: 0.266000; val_acc: 0.275000
# (Epoch 4 / 5) train acc: 0.287000; val_acc: 0.297000
# (Iteration 1001 / 1225) loss: 1.839518
# (Epoch 5 / 5) train acc: 0.344000; val_acc: 0.325000
#
# (Iteration 1 / 1225) loss: 2.302960
# (Epoch 0 / 5) train acc: 0.124000; val_acc: 0.129000
# (Epoch 1 / 5) train acc: 0.263000; val_acc: 0.283000
# (Epoch 2 / 5) train acc: 0.344000; val_acc: 0.326000
# (Iteration 501 / 1225) loss: 1.900553
# (Epoch 3 / 5) train acc: 0.344000; val_acc: 0.360000
# (Epoch 4 / 5) train acc: 0.401000; val_acc: 0.381000
# (Iteration 1001 / 1225) loss: 1.768848
# (Epoch 5 / 5) train acc: 0.399000; val_acc: 0.390000
#
# (Iteration 1 / 1225) loss: 4.796062
# (Epoch 0 / 5) train acc: 0.118000; val_acc: 0.122000
# (Epoch 1 / 5) train acc: 0.314000; val_acc: 0
# (Epoch 0 / 5) train acc: 0.121000; val_acc: 0.123000
# (Epoch 1 / 5) train acc: 0.208000; val_acc: 0.224000
# (Epoch 2 / 5) train acc: 0.239000; val_acc: 0.255000
# (Iteration 501 / 1225) loss: 2.430775
# (Epoch 3 / 5) train acc: 0.232000; val_acc: 0.270000
# (Epoch 4 / 5) train acc: 0.245000; val_acc: 0.268000
# (Iteration 1001 / 1225) loss: 2.351312
# (Epoch 5 / 5) train acc: 0.264000; val_acc: 0.268000
#
# (Iteration 1 / 1225) loss: 21.267469
# (Epoch 0 / 5) train acc: 0.093000; val_acc: 0.086000
# (Epoch 1 / 5) train acc: 0.183000; val_acc: 0.169000
# (Epoch 2 / 5) train acc: 0.212000; val_acc: 0.211000
# (Iteration 501 / 1225) loss: 18.635523
# (Epoch 3 / 5) train acc: 0.234000; val_acc: 0.234000
# (Epoch 4 / 5) train acc: 0.234000; val_acc: 0.247000
# (Iteration 1001 / 1225) loss: 18.330727
# (Epoch 5 / 5) train acc: 0.264000; val_acc: 0.254000
#
# (Iteration 1 / 1225) loss: 2.302558
# (Epoch 0 / 5) train acc: 0.157000; val_acc: 0.158000
# (Epoch 1 / 5) train acc: 0.389000; val_acc: 0.409000
# (Epoch 2 / 5) train acc: 0.453000; val_acc: 0.459000
# (Iteration 501 / 1225) loss: 1.692450
# (Epoch 3 / 5) train acc: 0.526000; val_acc: 0.479000
# (Epoch 4 / 5) train acc: 0.540000; val_acc: 0.481000
# (Iteration 1001 / 1225) loss: 1.492509
# (Epoch 5 / 5) train acc: 0.542000; val_acc: 0.480000
#
# (Iteration 1 / 1225) loss: 2.302967
# (Epoch 0 / 5) train acc: 0.175000; val_acc: 0.179000
# (Epoch 1 / 5) train acc: 0.445000; val_acc: 0.441000
# (Epoch 2 / 5) train acc: 0.494000; val_acc: 0.463000
# (Iteration 501 / 1225) loss: 1.408186
# (Epoch 3 / 5) train acc: 0.479000; val_acc: 0.510000
# (Epoch 4 / 5) train acc: 0.501000; val_acc: 0.494000
# (Iteration 1001 / 1225) loss: 1.185073
# (Epoch 5 / 5) train acc: 0.545000; val_acc: 0.495000
#
# Val_acc = 0.51
# Params: hidden=200, lr=0.001, reg=0.0, scale=0.001
#
# (Iteration 1 / 1225) loss: 5.706031
# (Epoch 0 / 5) train acc: 0.192000; val_acc: 0.158000
# (Epoch 1 / 5) train acc: 0.386000; val_acc: 0.380000
# (Epoch 2 / 5) train acc: 0.433000; val_acc: 0.405000
# (Iteration 501 / 1225) loss: 1.644082
# (Epoch 3 / 5) train acc: 0.468000; val_acc: 0.405000
# (Epoch 4 / 5) train acc: 0.504000; val_acc: 0.470000
# (Iteration 1001 / 1225) loss: 1.403055
# (Epoch 5 / 5) train acc: 0.514000; val_acc: 0.457000
#
# (Iteration 1 / 1225) loss: 2.303812
# (Epoch 0 / 5) train acc: 0.155000; val_acc: 0.164000
# (Epoch 1 / 5) train acc: 0.390000; val_acc: 0.392000
# (Epoch 2 / 5) train acc: 0.437000; val_acc: 0.464000
# (Iteration 501 / 1225) loss: 1.699239
# (Epoch 3 / 5) train acc: 0.483000; val_acc: 0.481000
# (Epoch 4 / 5) train acc: 0.473000; val_acc: 0.477000
# (Iteration 1001 / 1225) loss: 1.499016
# (Epoch 5 / 5) train acc: 0.505000; val_acc: 0.505000
#
# (Iteration 1 / 1225) loss: 2.428244
# (Epoch 0 / 5) train acc: 0.146000; val_acc: 0.168000
# (Epoch 1 / 5) train acc: 0.409000; val_acc: 0.438000
# (Epoch 2 / 5) train acc: 0.490000; val_acc: 0.454000
# (Iteration 501 / 1225) loss: 1.553206
# (Epoch 3 / 5) train acc: 0.500000; val_acc: 0.477000
# (Epoch 4 / 5) train acc: 0.523000; val_acc: 0.487000
# (Iteration 1001 / 1225) loss: 1.478019
# (Epoch 5 / 5) train acc: 0.540000; val_acc: 0.496000
#
# (Iteration 1 / 1225) loss: 17.233449
# (Epoch 0 / 5) train acc: 0.154000; val_acc: 0.163000
# (Epoch 1 / 5) train acc: 0.415000; val_acc: 0.445000
# (Epoch 2 / 5) train acc: 0.445000; val_acc: 0.427000
# (Iteration 501 / 1225) loss: 9.767298
# (Epoch 3 / 5) train acc: 0.476000; val_acc: 0.463000
# (Epoch 4 / 5) train acc: 0.503000; val_acc: 0.459000
# (Iteration 1001 / 1225) loss: 7.278244
# (Epoch 5 / 5) train acc: 0.549000; val_acc: 0.490000
#
# (Iteration 1 / 1225) loss: 2.304759
# (Epoch 0 / 5) train acc: 0.116000; val_acc: 0.119000
# (Epoch 1 / 5) train acc: 0.363000; val_acc: 0.385000
# (Epoch 2 / 5) train acc: 0.460000; val_acc: 0.457000
# (Iteration 501 / 1225) loss: 1.641059
# (Epoch 3 / 5) train acc: 0.524000; val_acc: 0.461000
# (Epoch 4 / 5) train acc: 0.497000; val_acc: 0.479000
# (Iteration 1001 / 1225) loss: 1.386345
# (Epoch 5 / 5) train acc: 0.502000; val_acc: 0.475000
#
# (Iteration 1 / 1225) loss: 2.520317
# (Epoch 0 / 5) train acc: 0.145000; val_acc: 0.164000
# (Epoch 1 / 5) train acc: 0.438000; val_acc: 0.446000
# (Epoch 2 / 5) train acc: 0.452000; val_acc: 0.458000
# (Iteration 501 / 1225) loss: 1.597906
# (Epoch 3 / 5) train acc: 0.512000; val_acc: 0.496000
# (Epoch 4 / 5) train acc: 0.515000; val_acc: 0.492000
# (Iteration 1001 / 1225) loss: 1.540533
# (Epoch 5 / 5) train acc: 0.516000; val_acc: 0.487000
#
# (Iteration 1 / 1225) loss: 27.196868
# (Epoch 0 / 5) train acc: 0.157000; val_acc: 0
# (Epoch 0 / 5) train acc: 0.096000; val_acc: 0.073000
# (Epoch 1 / 5) train acc: 0.199000; val_acc: 0.151000
# (Epoch 2 / 5) train acc: 0.234000; val_acc: 0.187000
# (Iteration 501 / 1225) loss: 2.388658
# (Epoch 3 / 5) train acc: 0.215000; val_acc: 0.218000
# (Epoch 4 / 5) train acc: 0.238000; val_acc: 0.238000
# (Iteration 1001 / 1225) loss: 2.326931
# (Epoch 5 / 5) train acc: 0.270000; val_acc: 0.252000
#
# (Iteration 1 / 1225) loss: 18.419226
# (Epoch 0 / 5) train acc: 0.078000; val_acc: 0.104000
# (Epoch 1 / 5) train acc: 0.197000; val_acc: 0.181000
# (Epoch 2 / 5) train acc: 0.203000; val_acc: 0.228000
# (Iteration 501 / 1225) loss: 14.864766
# (Epoch 3 / 5) train acc: 0.267000; val_acc: 0.250000
# (Epoch 4 / 5) train acc: 0.276000; val_acc: 0.264000
# (Iteration 1001 / 1225) loss: 14.875303
# (Epoch 5 / 5) train acc: 0.272000; val_acc: 0.267000
#
# (Iteration 1 / 1225) loss: 2.304733
# (Epoch 0 / 5) train acc: 0.101000; val_acc: 0.124000
# (Epoch 1 / 5) train acc: 0.195000; val_acc: 0.207000
# (Epoch 2 / 5) train acc: 0.237000; val_acc: 0.228000
# (Iteration 501 / 1225) loss: 2.304261
# (Epoch 3 / 5) train acc: 0.242000; val_acc: 0.241000
# (Epoch 4 / 5) train acc: 0.249000; val_acc: 0.254000
# (Iteration 1001 / 1225) loss: 2.302835
# (Epoch 5 / 5) train acc: 0.231000; val_acc: 0.248000
#
# (Iteration 1 / 1225) loss: 2.519806
# (Epoch 0 / 5) train acc: 0.105000; val_acc: 0.101000
# (Epoch 1 / 5) train acc: 0.189000; val_acc: 0.191000
# (Epoch 2 / 5) train acc: 0.258000; val_acc: 0.237000
# (Iteration 501 / 1225) loss: 2.483899
# (Epoch 3 / 5) train acc: 0.248000; val_acc: 0.252000
# (Epoch 4 / 5) train acc: 0.255000; val_acc: 0.263000
# (Iteration 1001 / 1225) loss: 2.394111
# (Epoch 5 / 5) train acc: 0.267000; val_acc: 0.264000
#
# (Iteration 1 / 1225) loss: 27.577773
# (Epoch 0 / 5) train acc: 0.108000; val_acc: 0.112000
# (Epoch 1 / 5) train acc: 0.174000; val_acc: 0.208000
# (Epoch 2 / 5) train acc: 0.228000; val_acc: 0.242000
# (Iteration 501 / 1225) loss: 24.222705
# (Epoch 3 / 5) train acc: 0.244000; val_acc: 0.270000
# (Epoch 4 / 5) train acc: 0.262000; val_acc: 0.283000
# (Iteration 1001 / 1225) loss: 23.805498
# (Epoch 5 / 5) train acc: 0.280000; val_acc: 0.292000
#
# Best val_acc = 0.51

# %% [markdown]
# # Проверка лучшей модели
#
# Запустите лучшую найденную модель на валидационной и тестовой выборках. Нужно получить более `48%` точности и на валидации, и на тесте.

# %%
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Точность на validation: ', (y_val_pred == data['y_val']).mean())
# Out:
# Точность на validation:  0.51

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
print('Точность на test: ', (y_test_pred == data['y_test']).mean())
# Out:
# Точность на test:  0.484

# %%
# Сохраняем лучшую модель
best_model.save("best_two_layer_net.npy")
# Out:
# best_two_layer_net.npy saved.

# %% [markdown]
# ## Теоретический вопрос 2
#
# После обучения нейросетевого классификатора может оказаться, что точность на тесте заметно ниже, чем на обучении. Как можно уменьшить этот разрыв? Выберите все подходящие варианты.
#
# 1. Обучать на более крупном датасете.
# 2. Добавить больше скрытых нейронов.
# 3. Увеличить силу регуляризации.
# 4. Ничего из перечисленного.
#
# ### Ваш ответ
#
# 1.Больше данных всегда лучше, модель будет лучше обобщать признаки
#
# 3.Может быть, скорее нужно подобрать оптимальную силу регуляции, чтобы ни недообучения, ни переобучения
